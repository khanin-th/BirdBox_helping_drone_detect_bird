# %% [markdown]
# # Bird Box
# Helping drone detects bird in the field of view, and potentially draw a plan to avoid it in advance.
#
# Bird categorizing task can be improved as much as 14% in accuracy via getting rid of background portion (using only part inside the bounding box of an image) [source](https://towardsdatascience.com/this-model-is-for-the-birds-6d55060d9074)

# %%
# importing stuffs
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import re
sns.set()

# %%
# https://stackoverflow.com/questions/43990046/tensorflow-blas-gemm-launch-failed
# This block to fix error:
# TensorFlow: Blas GEMM launch failed
import tensorflow as tf
configuration = tf.compat.v1.ConfigProto()
configuration.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=configuration)

# %%
# data source: NABirds data set provided by the Cornell Lab of Ornithology
# https://dl.allaboutbirds.org/nabirds
# https://www.birds.cornell.edu/home
file_path = r'E:\Download\nabirds.tar\nabirds'
# file_path = r'C:\Users\pui_s\Downloads\nabirds.tar\nabirds'
images = pd.read_csv(file_path + r'\images.txt', delimiter=' ', header=None)
images = images.rename({i:['id', 'image'][i] for i in range(2)}, axis='columns')
images['image'] = file_path + r'/images/' + images['image']
images
# Out:
#                                          id  \
# 0      0000139e-21dc-4d0c-bfe1-4cae3c85c829
# 1      0000d9fc-4e02-4c06-a0af-a55cfb16b12b
# 2      00019306-9d83-4334-b255-a447742edce3
# 3      0001afd4-99a1-4a67-b940-d419413e23b3
# 4      000332b8-997c-4540-9647-2f0a8495aecf
# ...                                     ...
# 48557  fff86e8b-795f-400a-91e8-565bbb8c453a
# 48558  fff926d7-ccad-4788-839e-97af2dd99372
# 48559  fffa33ef-a765-408d-8d66-6efc7f504c71
# 48560  ffff0d87-bc84-4ef2-a47e-a4bfa48502ce
# 48561  fffff3a5-2a75-47d0-887f-03871e3f9a37
#
#                                                    image
# 0      E:\Download\nabirds.tar\nabirds/images/0817/00...
# 1      E:\Download\nabirds.tar\nabirds/images/0860/00...
# 2      E:\Download\nabirds.tar\nabirds/images/0900/00...
# 3      E:\Download\nabirds.tar\nabirds/images/0645/00...
# 4      E:\Download\nabirds.tar\nabirds/images/0929/00...
# ...                                                  ...
# 48557  E:\Download\nabirds.tar\nabirds/images/0891/ff...
# 48558  E:\Download\nabirds.tar\nabirds/images/0660/ff...
# 48559  E:\Download\nabirds.tar\nabirds/images/0492/ff...
# 48560  E:\Download\nabirds.tar\nabirds/images/0372/ff...
# 48561  E:\Download\nabirds.tar\nabirds/images/0880/ff...
#
# [48562 rows x 2 columns]

# %%
images.iloc[0].image
# Out:
# 'C:\\Users\\pui_s\\Downloads\\nabirds.tar\\nabirds/images/0817/0000139e21dc4d0cbfe14cae3c85c829.jpg'

# %%
# plotting image
image_object = mpimg.imread(images.image.loc[0])
plt.imshow(image_object)
plt.show()

# %%
# reading bounding box data 
bound_box = pd.read_csv(file_path + r'\bounding_boxes.txt', delimiter=' ', header=None)
bound_box = bound_box.rename({i:['id', 'x', 'y', 'width', 'height'][i] for i in range(len(bound_box.columns))}, axis='columns')
bound_box
# Out:
#                                          id    x    y  width  height
# 0      0000139e-21dc-4d0c-bfe1-4cae3c85c829   83   59    128     228
# 1      0000d9fc-4e02-4c06-a0af-a55cfb16b12b  328   88    163     298
# 2      00019306-9d83-4334-b255-a447742edce3  174  367    219     378
# 3      0001afd4-99a1-4a67-b940-d419413e23b3  307  179    492     224
# 4      000332b8-997c-4540-9647-2f0a8495aecf  395  139    262     390
# ...                                     ...  ...  ...    ...     ...
# 48557  fff86e8b-795f-400a-91e8-565bbb8c453a  344  163    291     472
# 48558  fff926d7-ccad-4788-839e-97af2dd99372  330  180    339     671
# 48559  fffa33ef-a765-408d-8d66-6efc7f504c71  184   94    258     612
# 48560  ffff0d87-bc84-4ef2-a47e-a4bfa48502ce  102  210    461     688
# 48561  fffff3a5-2a75-47d0-887f-03871e3f9a37  281  164    524     279
#
# [48562 rows x 5 columns]

# %%
bird_df = pd.merge(images, bound_box, how='inner', on='id') # merging on id to ensure data from both tables merged correctly
bird_df
# Out:
#                                          id  \
# 0      0000139e-21dc-4d0c-bfe1-4cae3c85c829
# 1      0000d9fc-4e02-4c06-a0af-a55cfb16b12b
# 2      00019306-9d83-4334-b255-a447742edce3
# 3      0001afd4-99a1-4a67-b940-d419413e23b3
# 4      000332b8-997c-4540-9647-2f0a8495aecf
# ...                                     ...
# 48557  fff86e8b-795f-400a-91e8-565bbb8c453a
# 48558  fff926d7-ccad-4788-839e-97af2dd99372
# 48559  fffa33ef-a765-408d-8d66-6efc7f504c71
# 48560  ffff0d87-bc84-4ef2-a47e-a4bfa48502ce
# 48561  fffff3a5-2a75-47d0-887f-03871e3f9a37
#
#                                                    image    x    y  width  \
# 0      E:\Download\nabirds.tar\nabirds/images/0817/00...   83   59    128
# 1      E:\Download\nabirds.tar\nabirds/images/0860/00...  328   88    163
# 2      E:\Download\nabirds.tar\nabirds/images/0900/00...  174  367    219
# 3      E:\Download\nabirds.tar\nabirds/images/0645/00...  307  179    492
# 4      E:\Download\nabirds.tar\nabirds/images/0929/00...  395  139    262
# ...                                                  ...  ...  ...    ...
# 48557  E:\Download\nabirds.tar\nabirds/images/0891/ff...  344  163    291
# 48558  E:\Download\nabirds.tar\nabirds/images/0660/ff...  330  180    339
# 48559  E:\Download\nabirds.tar\nabirds/images/0492/ff...  184   94    258
# 48560  E:\Download\nabirds.tar\nabirds/images/0372/ff...  102  210    461
# 48561  E:\Download\nabirds.tar\nabirds/images/0880/ff...  281  164    524
#
#        height
# 0         228
# 1         298
# 2         378
# 3         224
# 4         390
# ...       ...
# 48557     472
# 48558     671
# 48559     612
# 48560     688
# 48561     279
#
# [48562 rows x 6 columns]

# %%
# plotting image with its bounding box
# idx = np.random.randint(low=0, high=len(bird_df))
# print('iloc: ', idx)
idx = 0
image_object = mpimg.imread(bird_df.image.iloc[idx])
plt.imshow(image_object)
x = [bird_df.iloc[idx]['x'], bird_df.iloc[idx]['x']+bird_df.iloc[idx]['width']]
y = [bird_df.iloc[idx]['y'], bird_df.iloc[idx]['y']+bird_df.iloc[idx]['height']]
sns.lineplot(x=[x[0], x[0], x[1], x[1]], y=[y[0], y[1], y[0], y[1]], color='red')
plt.show()

# %%
# will extract only those in 0817 folder for quick training 
# on a pretrained neural network
idx_0817 = []
s_temp = bird_df.image.str.split('/')
for each in bird_df.index:
    if '0817' in s_temp[each]:
        t=idx_0817.append(each)
# Out:
# 48561

# %%
bird_df.loc[idx_0817].iloc[0]
# Out:
# id                     0000139e-21dc-4d0c-bfe1-4cae3c85c829
# image     C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# x                                                        83
# y                                                        59
# width                                                   128
# height                                                  228
# Name: 0, dtype: object

# %%
max(bird_df.height.max(), bird_df.width.max())
# Out:
# 1024

# %%
# retreiving format for labelling
with open('template.xml', 'r') as f:
    out = f.readlines()
f.close()
out
temp_xml = out[:]
print(''.join(temp_xml))
# Out:
# <annotation>
# 	<folder>0817</folder>
# 	<filename>0000139e21dc4d0cbfe14cae3c85c829.jpg</filename>
# 	<path>C:\Users\pui_s\Downloads\nabirds.tar\nabirds\images\0817\0000139e21dc4d0cbfe14cae3c85c829.jpg</path>
# 	<source>
# 		<database>Unknown</database>
# 	</source>
# 	<size>
# 		<width>296</width>
# 		<height>341</height>
# 		<depth>3</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>bird</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>83</xmin>
# 			<ymin>59</ymin>
# 			<xmax>211</xmax>
# 			<ymax>287</ymax>
# 		</bndbox>
# 	</object>
# </annotation>

# %%
# looping through all the images in 0817 folder
for idx in idx_0817:
    temp_df = bird_df.loc[idx]
    file_name = temp_df.image.split('/')[-1]
    newFileName = file_name.split('.')[0]+'.xml'
    x, y = temp_df.x, temp_df.y
    w, h = temp_df.width, temp_df.height
    file_path = temp_df.image.replace('/', '\\').encode('unicode_escape').decode('ascii') # to ignore escape \U
    image_object = mpimg.imread(temp_df.image)
    height, width = image_object.shape[:2]
    
    
    # x and y coordinates
    assert w > 0 and h > 0
    temp_xml[-7] = re.sub(r'(?<=<xmin>)(.*)(?=</xmin>)', str(x), temp_xml[-7])
    temp_xml[-6] = re.sub(r'(?<=<ymin>)(.*)(?=</ymin>)', str(y), temp_xml[-6])
    temp_xml[-5] = re.sub(r'(?<=<xmax>)(.*)(?=</xmax>)', str(x+w), temp_xml[-5])
    temp_xml[-4] = re.sub(r'(?<=<ymax>)(.*)(?=</ymax>)', str(y+h), temp_xml[-4])

    # width and height
    temp_xml[8] = re.sub(r'(?<=<width>)(.*)(?=</width>)', str(width), temp_xml[8])
    temp_xml[9] = re.sub(r'(?<=<height>)(.*)(?=</height>)', str(height), temp_xml[9])

    # file path
    temp_xml[3] = re.sub(r'(?<=<path>)(.*)(?=</path>)', file_path, temp_xml[3])

    # file name
    temp_xml[2] = re.sub(r'(?<=<filename>)(.*)(?=</filename>)', file_name, temp_xml[2])

#     print(''.join(temp_xml))
    
    # saving the xml file
    print('saving: ' + '0817_labels\\' + newFileName)
    out_f = open('0817_labels\\' + newFileName, "w")
    out_f.write(''.join(temp_xml))
    out_f.close()
#     break
# Out:
# saving: 0817_labels\0000139e21dc4d0cbfe14cae3c85c829.xml
# saving: 0817_labels\01a472d8e93047a080aae4f958a2ef47.xml

# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c61163979a84> in <module>
#       1 idx = 0
# ----> 2 this_bird = bird_df.loc[idx_0817[idx]]
#       3 image_object = mpimg.imread(this_bird.image)
#       4 plt.imshow(image_object)
#
# NameError: name 'idx_0817' is not defined

# %%
# all labels
for idx in bird_df.index:
    temp_df = bird_df.loc[idx]
    file_name = temp_df.image.split('/')[-1]
    newFileName = file_name.split('.')[0]+'.xml'
    x, y = temp_df.x, temp_df.y
    w, h = temp_df.width, temp_df.height
    file_path = temp_df.image.replace('/', '\\').encode('unicode_escape').decode('ascii') # to ignore escape \U
    image_object = mpimg.imread(temp_df.image)
    height, width = image_object.shape[:2]
    folder = re.findall(r'[\d]{4}', temp_df.image)[0]
    
    # folder
    temp_xml[1] = re.sub(r'(?<=<folder>)(.*)(?=</folder>)', folder, temp_xml[1])
    
    # x and y coordinates
    assert w > 0 and h > 0
    temp_xml[-7] = re.sub(r'(?<=<xmin>)(.*)(?=</xmin>)', str(x), temp_xml[-7])
    temp_xml[-6] = re.sub(r'(?<=<ymin>)(.*)(?=</ymin>)', str(y), temp_xml[-6])
    temp_xml[-5] = re.sub(r'(?<=<xmax>)(.*)(?=</xmax>)', str(x+w), temp_xml[-5])
    temp_xml[-4] = re.sub(r'(?<=<ymax>)(.*)(?=</ymax>)', str(y+h), temp_xml[-4])

    # width and height
    temp_xml[8] = re.sub(r'(?<=<width>)(.*)(?=</width>)', str(width), temp_xml[8])
    temp_xml[9] = re.sub(r'(?<=<height>)(.*)(?=</height>)', str(height), temp_xml[9])

    # file path
    temp_xml[3] = re.sub(r'(?<=<path>)(.*)(?=</path>)', file_path, temp_xml[3])

    # file name
    temp_xml[2] = re.sub(r'(?<=<filename>)(.*)(?=</filename>)', file_name, temp_xml[2])

#     print(''.join(temp_xml))
    
    # saving the xml file
    print('saving: ' + 'labels\\' + newFileName)
    out_f = open('labels\\' + newFileName, "w")
    out_f.write(''.join(temp_xml))
    out_f.close()
# Out:
# saving: labels\0000139e21dc4d0cbfe14cae3c85c829.xml
# saving: labels\0000d9fc4e024c06a0afa55cfb16b12b.xml
# saving: labels\000193069d834334b255a447742edce3.xml
# saving: labels\0001afd499a14a67b940d419413e23b3.xml
# saving: labels\000332b8997c454096472f0a8495aecf.xml
# saving: labels\000343bd521549baab9c7c97a70ac1a5.xml
# saving: labels\0004ff8d0cc847ee94ba43352a8b9eb4.xml
# saving: labels\0007181fa7274481ad89591200c61b9d.xml
# saving: labels\00071e2081564bd8b5ca6445c2560ee5.xml
# saving: labels\0007acfcc0e643939ab602215a82ef63.xml
# saving: labels\00081fce2a744a9fb52b9bb8871a48e2.xml
# saving: labels\00085a7befcc4c08a83038477e749101.xml
# saving: labels\0009051ba76c4a27ac5dbf410aea7e0c.xml
# saving: labels\000948ee8c1940bb840372c665e7ffc3.xml
# saving: labels\00098273c6364b0eb615b6c03b00d39a.xml
# saving: labels\000c3c44dd8c4efe949e3adfd766d719.xml
# saving: labels\000d57361eff4207a5877b8f7115d529.xml
# saving: labels\000ef8cc723046a08415e13eb13bbc28.xml
# saving: labels\001037a2b6d14517b305c14a8bdf7963.xml
# saving: labels\00114d1f8049400385174449acd06059.xml
# saving: labels\0013bc9407e04ff6b1938da8f367486f.xml
# saving: labels\0015085a392b40a38d907af61f37e8f8.xml
# saving: labels\0015c3c30eac4e9e823a6b1c120e565f.xml
# saving: labels\0017839359ef4637a4139fc829cd66fd.xml
# saving: labels\034968f86faf4a0d8b086b8af7138fef.xml
# saving: labels\034aa65b173d441585e9462a29d96b7b.xml
# saving: labels\034ab30ef03d4a0b8a17001e25039d70.xml
# saving: labels\034c6ccd666541d7b03bf0d21b17b357.xml
# saving: labels\034c7fb20fd245ad83584968881f6153.xml
# saving: labels\03501e546c1c46b9aaebffaecce073ce.xml
# saving: labels\0355c15e9afe438183101954b672cb25.xml
# saving: labels\0356ba4629b64cef85f496a3fc49dc29.xml
# saving: labels\035706a329204f42898ad9bab538b134.xml
# saving: labels\03590a2730354def8f2a8e358d3226e7.xml
# saving: labels\0359739b7f8646718ea1d9c91f261cdf.xml
# saving: labels\035b5b4ea4924207b1fd584109b5556a.xml
# saving: labels\035c35c91ba14e25b7c5827dbe16fd70.xml
# saving: labels\03610854042d4980be31fd9e3b3101f5.xml
# saving: labels\0363102c7d6f4b0b81ab9da6e28aca90.xml
# saving: labels\03635e0ea97442258386b768135756c4.xml
# saving: labels\0364b9655d74443e8c6a8bfdb7b74b99.xml
# saving: labels\03666d4797664893a1c32934151644d4.xml
# saving: labels\03685c00b0dc4fafaafe2b2e528c675c.xml
# saving: labels\0368628f68ea476ca10192e43189de4f.xml
# saving: labels\036909e186f448b3a0861f287f7beac9.xml
# saving: labels\03698d0011a140d886a3532159698534.xml
# saving: labels\036b23050b45412c877c31424a571197.xml
# saving: labels\036b993eb17b4f6289407b635e632f85.xml
# saving: labels\036cbbf918504b8c952832d8b80675b1.xml
# saving: labels\036fba7c96374635853511ead2c1c728.xml
# saving: labels\0371f3f9a8a24a0a9e461e3804bf6fa9.xml
# saving: labels\03726667ff4840da807de07827c3c56e.xml
# saving: labels\037305c2265f45419b7f3a5dd724edb7.xml
# saving: labels\037309392dd840d5bd3ed75d042aa125.xml
# saving: labels\037391e5f894429e88a3812994790718.xml
# saving: labels\0373d8c4fe2a41efb559309f0ba2e8a4.xml
# saving: labels\0375fedc56f442cba1decb9ea1e00594.xml
# saving: labels\037744317fcc4caf99d3456c980c6cf7.xml
# saving: labels\037e0f3b0fa7462b88def88060660347.xml
# saving: labels\037eb32c6e5543cf93c27f0e0dac1304.xml
# saving: labels\037f57bbc9964deab39f6ed7f73f9eaa.xml
# saving: labels\037f79a6a56d485da0518ecffccff864.xml
# saving: labels\03806625a041454682714a1ed8040a7c.xml
# saving: labels\038112b5128d447ca4a3aee608c3cc6f.xml
# saving: labels\0384ba8f86f8472682bfb9773401eed3.xml
# saving: labels\0385ec3c00254f64a33c5ed905f48bae.xml
# saving: labels\03874cbfab5a4d44975921cc029c20aa.xml
# saving: labels\03899a8a37c246748956a3f65744ea5d.xml
# saving: labels\038a71f5ec9e46c3adbcfd41c765b5fd.xml
# saving: labels\038ab509d92544508360de8cfb51ffc2.xml
# saving: labels\038b48f1a9494d6e9813ec9ddc7764f3.xml
# saving: labels\038b96baa9b0481b8521e244d9d404ca.xml
# saving: labels\038c61b86f5043da9035682fbbf1d56b.xml
# saving: labels\038eb984c835459fb1a83d601594424c.xml
# saving: labels\042239c787f14b5899650162bc868fe9.xml
# saving: labels\0423cfacdabe466ab653503a3ce73f42.xml
# saving: labels\042464ea535141f1a5e15d896f6a69ba.xml
# saving: labels\04249d16a5b24cc7953235623d1e5fa1.xml
# saving: labels\0424b952a40e4e2fa87183e4f7a6f563.xml
# saving: labels\0426b94d5b0949c69b39a082c65ef740.xml
# saving: labels\0426cfacecc14b9b984e2c7a5b675f5a.xml
# saving: labels\0427148d124144a2a0bfb532d7ce0e7a.xml
# saving: labels\0427270b0e104458b7fe110415c6e67c.xml
# saving: labels\0427bbd744e340ee919fddcc0e0ecb95.xml
# saving: labels\04286f02bbf942b4a721a304a94058d6.xml
# saving: labels\042908ac6d3546db83f98ee314ac6e2b.xml
# saving: labels\0429212f8bd34f99b9a5459fc5f89b61.xml
# saving: labels\042a0aee608e414c96628ff4de79500f.xml
# saving: labels\042b9b43ca574b2ca1d5b7a2654b0202.xml
# saving: labels\042cd49741d8472bbb537d8bd1bd3619.xml
# saving: labels\0430a00d8a534ce8ba2a101e4ce1f2dc.xml
# saving: labels\043219db6c36469fbe7326e565c37b10.xml
# saving: labels\0433d056aa304f8a9aa1abbb951e4edd.xml
# saving: labels\04347740f8f648bb887af68babd0a0d4.xml
# saving: labels\043739d53a80403e98865a7e24b97565.xml
# saving: labels\04385015fe84413791c039476e2de6e7.xml
# saving: labels\0438aa2171224943978825ed3cb716be.xml
# saving: labels\043af9ebf2b4426eac5768b26ed3e01c.xml
# saving: labels\043ddb2171e647fe9c28dab8d36b513b.xml
# saving: labels\043f335863d343e58eb629de9162e499.xml
# saving: labels\044289e429f1473186b59228bc91c989.xml
# saving: labels\0445e14fd9ce407db68db3d21ad4f769.xml
# saving: labels\044612b33e714804884c77789f36f853.xml
# saving: labels\0446ea0ea7634d09adf0ea384770282a.xml
# saving: labels\04493fde361147a4860d494566252885.xml
# saving: labels\0449daee92974c1998d675d1e1ab8828.xml
# saving: labels\044be3c23d55497ea8503ca48c91ba05.xml
# saving: labels\044ce76d18d44f268c7abd682bdb6e04.xml
# saving: labels\044f491f68ec424eb60f88e41a793c18.xml
# saving: labels\044fce8d4c5d43c385ac2df47e0565f1.xml
# saving: labels\0450365d78e1462a999c2490fed4a737.xml
# saving: labels\04509048e6c848c98b047cfe95da42bc.xml
# saving: labels\04511df7f9a54f7ca1aa9acc49c2ed84.xml
# saving: labels\0451391b91584e33bfcc1a5339422882.xml
# saving: labels\0451fb661ab945ac99e445ce29b2613a.xml
# saving: labels\045276dabe524a53882638b36bab2b6d.xml
# saving: labels\0454fcd0f6b2405b962d7364592bf2b5.xml
# saving: labels\04576125124048219a5b6b9d913837b6.xml
# saving: labels\0457c36d868a4bdb851eb4c629792b6e.xml
# saving: labels\045a9b728ca4477aabe14d90d28dc0ff.xml
# saving: labels\045bd52ff9a34f4db5d76554e618bbba.xml
# saving: labels\045dc71186254740841a181018bd90cc.xml
# saving: labels\04608beaeec540669588cb8da41c36e1.xml
# saving: labels\0460dd1a714d429da0533516cd5b0ed9.xml
# saving: labels\fed8ff65dc31429cb3f78cdcbeddcbb1.xml
# saving: labels\feda0a721e0c45eaa00c4d90168fb2a1.xml
# saving: labels\fedc55bc817a4fbe8426863828c3d9a0.xml
# saving: labels\fedd16d8d3574cf6a5ea4d015f70c366.xml
# saving: labels\fedd37169f354b6da4e98c79c103fffe.xml
# saving: labels\fedd806586b4420c9c808b62484bd52e.xml
# saving: labels\fede57d434e84208b0db1495898f6d59.xml
# saving: labels\fee0f975c1624dbf9fac6e750a9483f9.xml
# saving: labels\fee16fe530e04782966fbc701e416256.xml
# saving: labels\fee25ab115284b3ba59a257773efd241.xml
# saving: labels\fee2ba1e076f4b1b9da7f6f4b11731f9.xml
# saving: labels\fee2e2a2f01d489088c9a00ae891e041.xml
# saving: labels\fee51809e20a4d6c937ec658938f7481.xml
# saving: labels\fee54a0112914b46b76181f426a65c0a.xml
# saving: labels\fee61d7f3ab241c390dd648c8be5c37e.xml
# saving: labels\fee66a180c9d4629bc57be0b67cfc965.xml
# saving: labels\fee9fa01dedc4837bc522023147f2079.xml
# saving: labels\feea50f2d16c470581f0810876a98a2f.xml
# saving: labels\feeb9125725d44908079699ace50b840.xml
# saving: labels\feec4527813449be887cbbbab6eac1d4.xml
# saving: labels\feed9013d8e24d74b9b3b7f8791702eb.xml
# saving: labels\feee40e823a5499a919aedd45b7c5e9a.xml
# saving: labels\feeeefb054c148cf82e45d6bcf74e6ee.xml
# saving: labels\fef1bf522e0b4afebf768ad91a958240.xml
# saving: labels\fef37f74755b4e5a87fc699545fe70f7.xml
# saving: labels\fef48364d02c4bb4b8cb367c0947bdc2.xml
# saving: labels\fef567a2c12144819af0ff108d199bbf.xml
# saving: labels\fef5cdab540b4d53b590987e852ddecf.xml
# saving: labels\fef7185ce1204ddbab6b529e81e39866.xml
# saving: labels\fefb7efededf47e59955b61931d740b5.xml
# saving: labels\fefcdd8dd2424e0fad050b2d16544af7.xml
# saving: labels\fefd22901b53437e9467528234697929.xml
# saving: labels\fefdeca8517a46628bbf3f9076649f84.xml
# saving: labels\feffb4db5f704fc1a5a784a3dc56a877.xml
# saving: labels\ff0029d8518b4d19bad5b7d4deb67daf.xml
# saving: labels\ff002c310593469691e5a5f0c7fa2053.xml
# saving: labels\ff00f70597e54ff693a4e9b08257ded7.xml
# saving: labels\ff01217072e94b5c8dc19b54bc032318.xml
# saving: labels\ff01d6e216624d928445936d42181b21.xml
# saving: labels\ff02e9e59ff447938a72ba76d7ae096a.xml
# saving: labels\ff035d74366042a5b08902fb3179c14f.xml
# saving: labels\ff088c77131d4ec5a107894abb89b11f.xml
# saving: labels\ff08f6fa3a1f4ed6851ad362d05d3b40.xml
# saving: labels\ff09b990dcfa4f5eb29094a1d6daa0b2.xml
# saving: labels\ff0dea382aff4f0e8cbb1671380ccfa3.xml
# saving: labels\ff1119f695e04e79877852470734b9ca.xml
# saving: labels\ff1270623d8c4c9b8bd46c4f1d24623a.xml
# saving: labels\ff12902826d24571b04f5b0fff83b2e1.xml
# saving: labels\ff12d2186644465a815fd2dba5011ad3.xml
# saving: labels\ff1456463fec45618296c698f0031916.xml
# saving: labels\ff15bd865b4f4a20a608e762a56aac9b.xml
# saving: labels\ff15cdfafc9b444e9884f3cb4eb34152.xml
# saving: labels\ff162786179d4a909a3b0c28f4e8cc22.xml
# saving: labels\ff17652d470c4730b57a5133d6b7d0cc.xml
# saving: labels\ff17b22c351348aaa472aabf5868b9c1.xml
# saving: labels\ff17e4d72e48440cb6e7ecbab57fac02.xml
# saving: labels\ff18a31748fe4d39ba6f95917901caff.xml
# saving: labels\ff18e7fa0bb4459a8ef62cca36c0d26d.xml
# saving: labels\ff1c52b637c845f28cc15b9291e7d092.xml
# saving: labels\ff1c53dce8fc42989540c011a8e29b1d.xml
# saving: labels\ff20ab9f9f744d0eb901352c3084c67d.xml
# saving: labels\ff2201ebee314cfd92934cbbccf82880.xml
# saving: labels\ff24087740c0415d98ab0f3b96b396a9.xml
# saving: labels\ff24e5a1bf254b13a7877f23a32f8ce6.xml
# saving: labels\ff26ad4dcbd24246b314c5e54b573f3d.xml
# saving: labels\ff280d35cbd14f15a2df646b5fe4864a.xml
# saving: labels\ff2b55522cb54c00918d026e0e72a0fd.xml
# saving: labels\ff2ca89bb0454e0d89b9235a4709cc47.xml
# saving: labels\ff2da6933b0847e09da890b436255cb9.xml
# saving: labels\ff30590f88604445a7146f83930f0847.xml
# saving: labels\ff310600912c4f4b823c8def22fcb8f0.xml
# saving: labels\ff31e022005643b5a7a220afa0c0ea83.xml
# saving: labels\ff32fbeee6c4474ba9b7135978d0e739.xml
# saving: labels\ff34553268a24aa0a89e8a60a0c3e8b3.xml
# saving: labels\ff34dec5393a4d149f07d097d2fe755a.xml
# saving: labels\ff37d6d7fb1d4e2c800df7ef443924e6.xml
# saving: labels\ff382c48cc6d4b01ab72ab1d0ac82235.xml
# saving: labels\ff3b20f4bd1d4ef6b16c9bded40a13c7.xml
# saving: labels\ff3ba9d2e5574797b83746a4f8d6f684.xml
# saving: labels\ff3e024b951d4acaa168c09c6507525d.xml
# saving: labels\ff3ec343854f40d3b20ae5730080aea5.xml
# saving: labels\ff3f55f016ac490999e281095a0be205.xml
# saving: labels\ff4192ee5a164de684149d92659c9e97.xml
# saving: labels\ff41bb8bb2ff4eb99a144ccfa016fbe6.xml
# saving: labels\ff4246699e14459b87cadeee949b7f60.xml
# saving: labels\ff44aaa3bea048f7be93145c7a9fa5ad.xml
# saving: labels\ff44c2b21b1b4243969c4f5c83477f41.xml
# saving: labels\ff46d9568c434f4680fb3bf721d99005.xml
# saving: labels\ff475e03d4c44ef3add313f46f28a642.xml
# saving: labels\ff478b456c9a4c3494816fd2e965a5e8.xml
# saving: labels\ff47af7de26a40bcb682d9a4985ea44b.xml
# saving: labels\ff482694087f4e7b84e8edd099e112e5.xml
# saving: labels\ff4d73387b11469fad81ce5077ff6a70.xml
# saving: labels\ff4e92034af0418881730d9cea884281.xml
# saving: labels\ff4f32d2a4e844d182963e130330cdc4.xml
# saving: labels\ff5090ffd4964e9286dfc3ebc03e89c0.xml
# saving: labels\ff8ea91c441f45c3a8cda8ca66b206e9.xml
# saving: labels\ff93cb5345d040b7bb804bec759f3251.xml
# saving: labels\ff9473f723834faeb670e822fa844f66.xml
# saving: labels\ff960751f5d8442f97401f4db81f6e0b.xml
# saving: labels\ff966557a72242cf84bc54a7bc8ab68e.xml
# saving: labels\ff982be7a2fb480a98c6f58c4657cd5c.xml
# saving: labels\ff9892a795dc4b76b372f1d90d842f09.xml
# saving: labels\ff9a3cf3a6604e79ac14b8484f7c96a6.xml
# saving: labels\ff9bda1f9e224cc1993866f045f479e8.xml
# saving: labels\ff9e173e9afa49978b4722a943f87778.xml
# saving: labels\ff9ee5ab6adb40e8bfc8047f0685c3ea.xml
# saving: labels\ff9ffa1509ee4cf7a687002f1e6048d8.xml
# saving: labels\ffa1258ff78841b1beaf8163ab422004.xml
# saving: labels\ffa1d7dd981e464095db0fd09fdb2af2.xml
# saving: labels\ffa207922fb440ae8c6fe2b6c6cdbe54.xml
# saving: labels\ffa49f17594b4ba0ba89a68d98cd1316.xml
# saving: labels\ffa49ffcee4a4929b79fdbf7d250c8ee.xml
# saving: labels\ffa5e8f619a14c23a307069b3c0497a8.xml
# saving: labels\ffa7720dd6ea43619eaa48d30ba7a997.xml
# saving: labels\ffa7bd6fda564dd6a8b4b54c5dcf1ea3.xml
# saving: labels\ffa808f512034fa4ba966ff9f4c5442a.xml
# saving: labels\ffa81728ade44d0d9a2d01b8d9508a3d.xml
# saving: labels\ffa827a7e3bb4d6ab4ffa836d3506498.xml
# saving: labels\ffacc94029904ada981509d8a44fb931.xml
# saving: labels\ffb175a2992040ce8ba9c44a7bab07ce.xml
# saving: labels\ffb545cb5b464530930594b1b59d47c1.xml
# saving: labels\ffb660153517494492877d297d874099.xml
# saving: labels\ffb6ae43fecb43669b5cc32467147ce4.xml
# saving: labels\ffb6d1ccc0aa405f90075df7740a268c.xml
# saving: labels\ffb6fb8a16c14132a7f51d1701778e6b.xml
# saving: labels\ffb950c5060f4e5b845c5e620f98bd2d.xml
# saving: labels\ffba94c12af949b780531df33d386a1a.xml
# saving: labels\ffbcff8dca784f81a89e7f6de4398e80.xml
# saving: labels\ffbd30a6cda04a028de8c4496b4d489b.xml
# saving: labels\ffbf63ab160246b69cadaae0eb4ca8e1.xml
# saving: labels\ffc08b58fa4644bc8f9121770f152b21.xml
# saving: labels\ffc1351cef20401b9a9d08149bf8ce2e.xml
# saving: labels\ffc3db6fd3f54388afca12d1bc331ad2.xml
# saving: labels\ffc41f53725841d5804d8423a29c10ee.xml
# saving: labels\ffc431f4a61f4b9b9de1de000fa27a85.xml
# saving: labels\ffc48ced47fe498093cce8321624764d.xml
# saving: labels\ffc60a3801bb480b906d268179a72985.xml
# saving: labels\ffc6fd34ae434890b512e68d0c4ba4b5.xml
# saving: labels\ffc7e9dd6ccb491fb3703f6bb3566d60.xml
# saving: labels\ffc850705e134ec7a517551494fbd0e3.xml
# saving: labels\ffc9256d28fd425fb971cf1119c48aa1.xml
# saving: labels\ffc9ec833082491c866154b5deb2f3a6.xml
# saving: labels\ffcce05ab38d4570b3dc751e89b7790a.xml
# saving: labels\ffcd453ce52d4cbe882173845076e70a.xml
# saving: labels\ffcdbe0c93944837a0e36acd316bcea1.xml
# saving: labels\ffce0ad4a6814bd6a68ad86bac118168.xml
# saving: labels\ffcf1220d4314d6c9149d311d3869d01.xml
# saving: labels\ffcf8a0b71184cba966ee6e26b77df73.xml
# saving: labels\ffd04d1d9ed64e26989173282f922d4d.xml
# saving: labels\ffd07702bcad453c9ceade587a49e626.xml
# saving: labels\ffd20554c658487c87e6d1fc0cc25cbe.xml
# saving: labels\ffd7beb9f4334bb09d69c1762519058e.xml
# saving: labels\ffd8849bafe644509ad0cc7a3bc042fd.xml
# saving: labels\ffd98522eecc4284a5a333eb55fb2ed7.xml
# saving: labels\ffdb192d45f64e50a1102cafc4205af9.xml
# saving: labels\ffdde72c10764e339f2ebd4b8b3ea75c.xml
# saving: labels\ffde854c059145489d3170f6c2ebf95a.xml
# saving: labels\ffe130da05ca491aa192396f829d7503.xml
# saving: labels\ffe27f604953462d91732678729c16ae.xml
# saving: labels\ffe4e24b4ccf4815b8c6c9eb38046b58.xml
# saving: labels\ffe4e8607d6943efa9196ecbc1b11203.xml
# saving: labels\ffea57f892b6428ebd5070ae3485b3ce.xml
# saving: labels\ffeaafac45dd458ca4a37be478e1106f.xml
# saving: labels\ffebf04388244f95aa9592a00c53a7cd.xml
# saving: labels\ffed6979182845c8a03a009466a5dc0d.xml
# saving: labels\ffedea2a9fa44e66a4aa8affda2d157c.xml
# saving: labels\ffee11a1bc744218a461f730d2133816.xml
# saving: labels\ffef2e23edd7422188a8074ac0773d77.xml
# saving: labels\ffef9325d3214129825d2d7dddeeb824.xml
# saving: labels\fff0b2c35ab34c64b160a77398fe5a46.xml
# saving: labels\fff1d97b2ac3410d8c6d7430470bb951.xml
# saving: labels\fff3ec3907d44600b75312013066277f.xml
# saving: labels\fff86e8b795f400a91e8565bbb8c453a.xml
# saving: labels\fff926d7ccad4788839e97af2dd99372.xml
# saving: labels\fffa33efa765408d8d666efc7f504c71.xml
# saving: labels\ffff0d87bc844ef2a47ea4bfa48502ce.xml
# saving: labels\fffff3a52a7547d0887f03871e3f9a37.xml

# %%
# verifying the labelling
idx = 99
this_bird = bird_df.loc[idx]
image_object = mpimg.imread(this_bird.image)
plt.imshow(image_object)

# %%
bird_df.loc[idx]
# Out:
# id                     0078fca2-f5db-4e35-939f-499c14f06846
# image     E:\Download\nabirds.tar\nabirds/images/0912/00...
# x                                                       144
# y                                                       247
# width                                                   639
# height                                                  347
# Name: 99, dtype: object

# %%
image_object.shape
# Out:
# (682, 1024, 3)

# %%
# moving files
import shutil

original = r'E:\Download\nabirds.tar\nabirds\images\0295'
target = r'E:\Download\TensorflowObjectDetection\TFODCourse\Tensorflow\workspace\images\train'

shutil.copy(original,target)

# %%
# using EfficientDet

# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
    while "models" in pathlib.Path.cwd().parts:
        os.chdir('..')
elif not pathlib.Path('models').exists():
    # !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# Updating files:  57% (1480/2584)
# Updating files:  58% (1499/2584)
# Updating files:  59% (1525/2584)
# Updating files:  60% (1551/2584)
# Updating files:  61% (1577/2584)
# Updating files:  62% (1603/2584)
# Updating files:  63% (1628/2584)
# Updating files:  64% (1654/2584)
# Updating files:  65% (1680/2584)
# Updating files:  66% (1706/2584)
# Updating files:  67% (1732/2584)
# Updating files:  68% (1758/2584)
# Updating files:  69% (1783/2584)
# Updating files:  70% (1809/2584)
# Updating files:  71% (1835/2584)
# Updating files:  72% (1861/2584)
# Updating files:  73% (1887/2584)
# Updating files:  74% (1913/2584)
# Updating files:  75% (1938/2584)
# Updating files:  76% (1964/2584)
# Updating files:  77% (1990/2584)
# Updating files:  78% (2016/2584)
# Updating files:  79% (2042/2584)
# Updating files:  80% (2068/2584)
# Updating files:  81% (2094/2584)
# Updating files:  82% (2119/2584)
# Updating files:  83% (2145/2584)
# Updating files:  84% (2171/2584)
# Updating files:  85% (2197/2584)
# Updating files:  86% (2223/2584)
# Updating files:  87% (2249/2584)
# Updating files:  88% (2274/2584)
# Updating files:  89% (2300/2584)
# Updating files:  90% (2326/2584)
# Updating files:  91% (2352/2584)
# Updating files:  92% (2378/2584)
# Updating files:  93% (2404/2584)
# Updating files:  94% (2429/2584)
# Updating files:  95% (2455/2584)
# Updating files:  96% (2481/2584)
# Updating files:  97% (2507/2584)
# Updating files:  98% (2533/2584)
# Updating files:  99% (2559/2584)
# Updating files: 100% (2584/2584)
# Updating files: 100% (2584/2584), done.

# %%
# %%bash
# # Install the Object Detection API
#
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf2/setup.py .
# python -m pip install .
# Out:
# Couldn't find program: 'bash'

# %%
import matplotlib
import matplotlib.pyplot as plt

import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf


from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import colab_utils
from object_detection.builders import model_builder

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-130-42ea925d969f> in <module>
#      17
#      18
# ---> 19 from object_detection.utils import label_map_util
#      20 from object_detection.utils import config_util
#      21 from object_detection.utils import visualization_utils as viz_utils
#
# ~\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research\object_detection\utils\label_map_util.py in <module>
#      27 import tensorflow.compat.v1 as tf
#      28 from google.protobuf import text_format
# ---> 29 from object_detection.protos import string_int_label_map_pb2
#      30
#      31 _LABEL_OFFSET = 1
#
# ImportError: cannot import name 'string_int_label_map_pb2' from 'object_detection.protos' (C:\Users\pui_s\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research\object_detection\protos\__init__.py)

# %%
import sys
sys.path
if r'C:\Users\pui_s\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research' not in sys.path:
    sys.path.insert(0, r'C:\Users\pui_s\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research')

# %%
sys.path
# Out:
# ['C:\\Users\\pui_s\\Documents\\concordia-bootcamps\\FinalProject-BirdBox\\BirdBox_helping_drone_detect_bird\\models\\research',
#  'C:\\Users\\pui_s\\Documents\\concordia-bootcamps\\FinalProject-BirdBox\\BirdBox_helping_drone_detect_bird',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\python39.zip',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\DLLs',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\lib',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39',
#  '',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\win32',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\win32\\lib',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\Pythonwin',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\IPython\\extensions',
#  'C:\\Users\\pui_s\\.ipython']

# %%
# https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md

# %%
# !py -m pip list
# Out:
# Package                  Version
# ------------------------ -------------------
# absl-py                  0.12.0
# anyio                    3.2.0
# argon2-cffi              20.1.0
# astor                    0.8.1
# astunparse               1.6.3
# async-generator          1.10
# attrs                    21.2.0
# autograd                 1.3
# autograd-gamma           0.5.0
# Babel                    2.9.1
# backcall                 0.2.0
# bash_kernel              0.7.2
# beautifulsoup4           4.9.3
# bleach                   3.3.0
# bs4                      0.0.1
# cachetools               4.2.2
# certifi                  2020.12.5
# cffi                     1.14.5
# chardet                  3.0.4
# Christofides             1.0.1
# click                    8.0.1
# colorama                 0.4.4
# configparser             5.0.2
# cycler                   0.10.0
# Cython                   0.29.24
# decorator                4.4.2
# defusedxml               0.7.1
# dload                    0.6
# entrypoints              0.3
# fake-useragent           0.1.11
# findspark                1.4.2
# Flask                    2.0.1
# flatbuffers              1.12
# formulaic                0.2.3
# future                   0.18.2
# gast                     0.4.0
# gensim                   4.0.1
# gevent                   21.1.2
# google-api-core          1.31.0
# google-auth              1.30.1
# google-auth-oauthlib     0.4.4
# google-cloud-core        1.7.1
# google-pasta             0.2.0
# googleapis-common-protos 1.53.0
# greenlet                 1.1.0
# grpcio                   1.34.1
# h11                      0.9.0
# h2                       3.2.0
# h5py                     3.1.0
# hiveplot                 2017.10.17.21.7
# hmmlearn                 0.2.5
# hpack                    3.0.0
# hstspreload              2021.7.5
# httpcore                 0.9.1
# httpx                    0.13.3
# hyperframe               5.2.0
# idna                     2.10
# imageio                  2.9.0
# interface-meta           1.2.3
# ipykernel                5.5.5
# ipython                  7.23.1
# ipython-genutils         0.2.0
# ipywidgets               7.6.3
# itsdangerous             2.0.1
# Janitor                  0.1.1
# jedi                     0.18.0
# Jinja2                   3.0.1
# joblib                   1.0.1
# json5                    0.9.5
# jsonschema               3.2.0
# jupyter                  1.0.0
# jupyter-client           6.1.12
# jupyter-console          6.4.0
# jupyter-core             4.7.1
# jupyter-server           1.8.0
# jupyterlab               3.0.16
# jupyterlab-pygments      0.1.2
# jupyterlab-server        2.6.0
# jupyterlab-widgets       1.0.0
# Keras                    2.4.3
# keras-nightly            2.5.0.dev2021032900
# Keras-Preprocessing      1.1.2
# kiwisolver               1.3.1
# lifelines                0.26.0
# linearmodels             4.24
# llvmlite                 0.36.0
# lxml                     4.6.3
# lyricsgenius             3.0.1
# Markdown                 3.3.4
# MarkupSafe               2.0.1
# matplotlib               3.4.2
# matplotlib-inline        0.1.2
# mistune                  0.8.4
# more-itertools           8.8.0
# mpmath                   1.2.1
# munkres                  1.1.4
# mypy-extensions          0.4.3
# nbclassic                0.3.1
# nbclient                 0.5.3
# nbconvert                6.0.7
# nbformat                 5.1.3
# nest-asyncio             1.5.1
# networkx                 2.5.1
# nltk                     3.6.2
# notebook                 6.4.0
# numba                    0.53.1
# numpy                    1.19.5
# nxviz                    0.6.3
# oauthlib                 3.1.0
# opencv-python            4.5.2.54
# opt-einsum               3.3.0
# packaging                20.9
# palettable               3.3.0
# pandas                   1.2.4
# pandas-datareader        0.9.0
# pandocfilters            1.4.3
# parso                    0.8.2
# patsy                    0.5.1
# pexpect                  4.8.0
# pickleshare              0.7.5
# Pillow                   8.2.0
# pip                      21.2.1
# prometheus-client        0.10.1
# prompt-toolkit           3.0.18
# property-cached          1.6.4
# protobuf                 3.17.1
# ptyprocess               0.7.0
# py4j                     0.10.9
# pyasn1                   0.4.8
# pyasn1-modules           0.2.8
# pycodestyle              2.3.1
# pycparser                2.20
# Pygments                 2.9.0
# pyhdfe                   0.1.0
# pynndescent              0.5.3
# pyparsing                2.4.7
# pyprojroot               0.2.0
# pyrsistent               0.17.3
# pyspark                  3.1.2
# python-dateutil          2.8.1
# python-Levenshtein       0.12.2
# python-magic             0.4.22
# python-resize-image      1.1.19
# pytz                     2021.1
# pywin32                  300
# pywinpty                 1.1.1
# PyYAML                   5.4.1
# pyzmq                    22.0.3
# qtconsole                5.1.0
# QtPy                     1.9.0
# regex                    2021.7.6
# requests                 2.25.1
# requests-oauthlib        1.3.0
# rfc3986                  1.5.0
# rsa                      4.7.2
# scikit-learn             0.24.2
# scipy                    1.6.3
# seaborn                  0.11.1
# selenium                 3.141.0
# Send2Trash               1.5.0
# setuptools               56.0.0
# six                      1.15.0
# smart-open               5.1.0
# sniffio                  1.2.0
# soupsieve                2.2.1
# splinter                 0.14.0
# statsmodels              0.12.2
# sympy                    1.8
# tensorboard              2.5.0
# tensorboard-data-server  0.6.1
# tensorboard-plugin-wit   1.8.0
# tensorflow-estimator     2.5.0
# tensorflow-gpu           2.5.0
# tensorflow-hub           0.12.0
# termcolor                1.1.0
# terminado                0.10.0
# testpath                 0.5.0
# threadpoolctl            2.1.0
# tornado                  6.1
# tqdm                     4.61.1
# traitlets                5.0.5
# typing-extensions        3.7.4.3
# umap-learn               0.5.1
# Unidecode                1.2.0
# urllib3                  1.26.4
# wcwidth                  0.2.5
# webencodings             0.5.1
# websocket-client         1.1.0
# Werkzeug                 2.0.1
# wheel                    0.36.2
# widgetsnbextension       3.5.1
# wikipedia                1.4.0
# wrapt                    1.12.1
# wsgi-oauth2              0.2.2
# xvfbwrapper              0.2.9
# zope.event               4.5.0
# zope.interface           5.4.0
