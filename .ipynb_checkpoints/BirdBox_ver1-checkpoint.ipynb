# %% [markdown]
# # Bird Box
# Helping drone detects bird in the field of view, and potentially draw a plan to avoid it in advance.
#
# Bird categorizing task can be improved as much as 14% in accuracy via getting rid of background portion (using only part inside the bounding box of an image) [source](https://towardsdatascience.com/this-model-is-for-the-birds-6d55060d9074)

# %%
# importing stuffs
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import re
sns.set()

# %%
# https://stackoverflow.com/questions/43990046/tensorflow-blas-gemm-launch-failed
# This block to fix error:
# TensorFlow: Blas GEMM launch failed
import tensorflow as tf
configuration = tf.compat.v1.ConfigProto()
configuration.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=configuration)

# %%
# data source: NABirds data set provided by the Cornell Lab of Ornithology
# https://dl.allaboutbirds.org/nabirds
# https://www.birds.cornell.edu/home
# file_path = r'E:\Download\nabirds.tar\nabirds'
file_path = r'C:\Users\pui_s\Downloads\nabirds.tar\nabirds'
images = pd.read_csv(file_path + r'\images.txt', delimiter=' ', header=None)
images = images.rename({i:['id', 'image'][i] for i in range(2)}, axis='columns')
images['image'] = file_path + r'/images/' + images['image']
images
# Out:
#                                          id  \
# 0      0000139e-21dc-4d0c-bfe1-4cae3c85c829
# 1      0000d9fc-4e02-4c06-a0af-a55cfb16b12b
# 2      00019306-9d83-4334-b255-a447742edce3
# 3      0001afd4-99a1-4a67-b940-d419413e23b3
# 4      000332b8-997c-4540-9647-2f0a8495aecf
# ...                                     ...
# 48557  fff86e8b-795f-400a-91e8-565bbb8c453a
# 48558  fff926d7-ccad-4788-839e-97af2dd99372
# 48559  fffa33ef-a765-408d-8d66-6efc7f504c71
# 48560  ffff0d87-bc84-4ef2-a47e-a4bfa48502ce
# 48561  fffff3a5-2a75-47d0-887f-03871e3f9a37
#
#                                                    image
# 0      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 1      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 2      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 3      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 4      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# ...                                                  ...
# 48557  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 48558  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 48559  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 48560  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# 48561  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
#
# [48562 rows x 2 columns]

# %%
images.iloc[0].image
# Out:
# 'C:\\Users\\pui_s\\Downloads\\nabirds.tar\\nabirds/images/0817/0000139e21dc4d0cbfe14cae3c85c829.jpg'

# %%
# plotting image
image_object = mpimg.imread(images.image.loc[0])
plt.imshow(image_object)
plt.show()

# %%
# reading bounding box data 
bound_box = pd.read_csv(file_path + r'\bounding_boxes.txt', delimiter=' ', header=None)
bound_box = bound_box.rename({i:['id', 'x', 'y', 'width', 'height'][i] for i in range(len(bound_box.columns))}, axis='columns')
bound_box
# Out:
#                                          id    x    y  width  height
# 0      0000139e-21dc-4d0c-bfe1-4cae3c85c829   83   59    128     228
# 1      0000d9fc-4e02-4c06-a0af-a55cfb16b12b  328   88    163     298
# 2      00019306-9d83-4334-b255-a447742edce3  174  367    219     378
# 3      0001afd4-99a1-4a67-b940-d419413e23b3  307  179    492     224
# 4      000332b8-997c-4540-9647-2f0a8495aecf  395  139    262     390
# ...                                     ...  ...  ...    ...     ...
# 48557  fff86e8b-795f-400a-91e8-565bbb8c453a  344  163    291     472
# 48558  fff926d7-ccad-4788-839e-97af2dd99372  330  180    339     671
# 48559  fffa33ef-a765-408d-8d66-6efc7f504c71  184   94    258     612
# 48560  ffff0d87-bc84-4ef2-a47e-a4bfa48502ce  102  210    461     688
# 48561  fffff3a5-2a75-47d0-887f-03871e3f9a37  281  164    524     279
#
# [48562 rows x 5 columns]

# %%
bird_df = pd.merge(images, bound_box, how='inner', on='id') # merging on id to ensure data from both tables merged correctly
bird_df
# Out:
#                                          id  \
# 0      0000139e-21dc-4d0c-bfe1-4cae3c85c829
# 1      0000d9fc-4e02-4c06-a0af-a55cfb16b12b
# 2      00019306-9d83-4334-b255-a447742edce3
# 3      0001afd4-99a1-4a67-b940-d419413e23b3
# 4      000332b8-997c-4540-9647-2f0a8495aecf
# ...                                     ...
# 48557  fff86e8b-795f-400a-91e8-565bbb8c453a
# 48558  fff926d7-ccad-4788-839e-97af2dd99372
# 48559  fffa33ef-a765-408d-8d66-6efc7f504c71
# 48560  ffff0d87-bc84-4ef2-a47e-a4bfa48502ce
# 48561  fffff3a5-2a75-47d0-887f-03871e3f9a37
#
#                                                    image    x    y  width  \
# 0      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...   83   59    128
# 1      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  328   88    163
# 2      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  174  367    219
# 3      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  307  179    492
# 4      C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  395  139    262
# ...                                                  ...  ...  ...    ...
# 48557  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  344  163    291
# 48558  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  330  180    339
# 48559  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  184   94    258
# 48560  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  102  210    461
# 48561  C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...  281  164    524
#
#        height
# 0         228
# 1         298
# 2         378
# 3         224
# 4         390
# ...       ...
# 48557     472
# 48558     671
# 48559     612
# 48560     688
# 48561     279
#
# [48562 rows x 6 columns]

# %%
# plotting image with its bounding box
# idx = np.random.randint(low=0, high=len(bird_df))
# print('iloc: ', idx)
idx = 0
image_object = mpimg.imread(bird_df.image.iloc[idx])
plt.imshow(image_object)
x = [bird_df.iloc[idx]['x'], bird_df.iloc[idx]['x']+bird_df.iloc[idx]['width']]
y = [bird_df.iloc[idx]['y'], bird_df.iloc[idx]['y']+bird_df.iloc[idx]['height']]
sns.lineplot(x=[x[0], x[0], x[1], x[1]], y=[y[0], y[1], y[0], y[1]], color='red')
plt.show()

# %%
# will extract only those in 0817 folder for quick training 
# on a pretrained neural network
idx_0817 = []
s_temp = bird_df.image.str.split('/')
for each in bird_df.index:
    if '0817' in s_temp[each]:
        t=idx_0817.append(each)
# Out:
# 48561

# %%
bird_df.loc[idx_0817].iloc[0]
# Out:
# id                     0000139e-21dc-4d0c-bfe1-4cae3c85c829
# image     C:\Users\pui_s\Downloads\nabirds.tar\nabirds/i...
# x                                                        83
# y                                                        59
# width                                                   128
# height                                                  228
# Name: 0, dtype: object

# %%
max(bird_df.height.max(), bird_df.width.max())
# Out:
# 1024

# %%
# retreiving format for labelling
with open('template.xml', 'r') as f:
    out = f.readlines()
f.close()
out
temp_xml = out[:]
print(''.join(temp_xml))
# Out:
# <annotation>
# 	<folder>0817</folder>
# 	<filename>0000139e21dc4d0cbfe14cae3c85c829.jpg</filename>
# 	<path>C:\Users\pui_s\Downloads\nabirds.tar\nabirds\images\0817\0000139e21dc4d0cbfe14cae3c85c829.jpg</path>
# 	<source>
# 		<database>Unknown</database>
# 	</source>
# 	<size>
# 		<width>296</width>
# 		<height>341</height>
# 		<depth>3</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>bird</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>83</xmin>
# 			<ymin>59</ymin>
# 			<xmax>211</xmax>
# 			<ymax>287</ymax>
# 		</bndbox>
# 	</object>
# </annotation>

# %%
# looping through all the images in 0817 folder
for idx in idx_0817:
    temp_df = bird_df.loc[idx]
    file_name = temp_df.image.split('/')[-1]
    newFileName = file_name.split('.')[0]+'.xml'
    x, y = temp_df.x, temp_df.y
    w, h = temp_df.width, temp_df.height
    file_path = temp_df.image.replace('/', '\\').encode('unicode_escape').decode('ascii') # to ignore escape \U
    image_object = mpimg.imread(temp_df.image)
    height, width = image_object.shape[:2]
    
    
    # x and y coordinates
    assert w > 0 and h > 0
    temp_xml[-7] = re.sub(r'(?<=<xmin>)(.*)(?=</xmin>)', str(x), temp_xml[-7])
    temp_xml[-6] = re.sub(r'(?<=<ymin>)(.*)(?=</ymin>)', str(y), temp_xml[-6])
    temp_xml[-5] = re.sub(r'(?<=<xmax>)(.*)(?=</xmax>)', str(x+w), temp_xml[-5])
    temp_xml[-4] = re.sub(r'(?<=<ymax>)(.*)(?=</ymax>)', str(y+h), temp_xml[-4])

    # width and height
    temp_xml[8] = re.sub(r'(?<=<width>)(.*)(?=</width>)', str(width), temp_xml[8])
    temp_xml[9] = re.sub(r'(?<=<height>)(.*)(?=</height>)', str(height), temp_xml[9])

    # file path
    temp_xml[3] = re.sub(r'(?<=<path>)(.*)(?=</path>)', file_path, temp_xml[3])

    # file name
    temp_xml[2] = re.sub(r'(?<=<filename>)(.*)(?=</filename>)', file_name, temp_xml[2])

#     print(''.join(temp_xml))
    
    # saving the xml file
    print('saving: ' + '0817_labels\\' + newFileName)
    out_f = open('0817_labels\\' + newFileName, "w")
    out_f.write(''.join(temp_xml))
    out_f.close()
#     break
# Out:
# saving: 0817_labels\0000139e21dc4d0cbfe14cae3c85c829.xml
# saving: 0817_labels\01a472d8e93047a080aae4f958a2ef47.xml
# saving: 0817_labels\036fba7c96374635853511ead2c1c728.xml
# saving: 0817_labels\07814887f59b44cb9b7f399999634fba.xml
# saving: 0817_labels\0822865741de43128a6a6c8897387975.xml
# saving: 0817_labels\0b277615eb6e499da2fc26525aa6e60e.xml
# saving: 0817_labels\110f7a2a05cd488fb15425588f75b80e.xml
# saving: 0817_labels\148631327cc44e1caebe38671d1b54c0.xml
# saving: 0817_labels\15118d82ede04508b25309ea9854a659.xml
# saving: 0817_labels\16da4080692342d28d3fa9328cab8c0a.xml
# saving: 0817_labels\19f1ceead89e4191ab362c096de940c8.xml
# saving: 0817_labels\1a68d370bb664fa8b761c3fc3f6e417c.xml
# saving: 0817_labels\1d04afaa687443f5a5dac6f5deebd45b.xml
# saving: 0817_labels\2033ce2dc2e84cc5ba1f86944124cccb.xml
# saving: 0817_labels\223a4eec9f8b42099126f33a78c08783.xml
# saving: 0817_labels\2d5dedcefc0e4ff9841450c32b3d3466.xml
# saving: 0817_labels\2d6cbc1bade24df5984547b9f92fb51b.xml
# saving: 0817_labels\2d9d025b88c34a1ebf9eb88f21f23ad8.xml
# saving: 0817_labels\33a49b0ff92e44c4b4fc1be0833777e9.xml
# saving: 0817_labels\35c330bf6765474b93a6590ea1252820.xml
# saving: 0817_labels\3e1d6eddde79438999150ee1a4093eb3.xml
# saving: 0817_labels\3eaf9800ee7149a48d1d699c3b305ed6.xml
# saving: 0817_labels\3ef01d6714324fddba5c620dadf4428f.xml
# saving: 0817_labels\3f03c82563a345958e3982fa5701d6fe.xml
# saving: 0817_labels\4252ce0b6c5b43ce85f4c8ed96fa8887.xml
# saving: 0817_labels\486df3165c6c44d1a6f5a956add3074e.xml
# saving: 0817_labels\4c5236036a484c59bfc115caee7fe278.xml
# saving: 0817_labels\4c66e80761e84cbca88aa18138b94e88.xml
# saving: 0817_labels\4f8a409e1184421aaab8e7d8518ac554.xml
# saving: 0817_labels\53efb265d28244ed8c2db84492401c05.xml
# saving: 0817_labels\540c7c3ef66e445f85ed2b9385f36ea2.xml
# saving: 0817_labels\559fe998131e42f684854dfd31f84658.xml
# saving: 0817_labels\560518510b4c48ee939c223282466f1c.xml
# saving: 0817_labels\5d3efa649acf49d593843a66472e217c.xml
# saving: 0817_labels\5f25f294a2564743a7c330ece9702f91.xml
# saving: 0817_labels\604853ac855e477a9c3a921d0d54d906.xml
# saving: 0817_labels\696978df53ad4a08a2c9ec272c6a3982.xml
# saving: 0817_labels\6a9a52f4d9f340cda1bfb6ab378b3ce7.xml
# saving: 0817_labels\6c292e68c99a44f6855c154c6a8288ba.xml
# saving: 0817_labels\72bd128c6fec44aaae6a55192bd5f805.xml
# saving: 0817_labels\72c1b2820e724b0e86b1c728b3d43ca9.xml
# saving: 0817_labels\75132bbb9c70449f958f4f2d4ca07f51.xml
# saving: 0817_labels\7af5d74c114e489790a5664928afd285.xml
# saving: 0817_labels\7e3ab9c7b620401393fe286bbd8aa59d.xml
# saving: 0817_labels\7ff291daf29346f0a8638ae836b804fa.xml
# saving: 0817_labels\867baa3c63c1421291a5e32d921441df.xml
# saving: 0817_labels\87319a4cd7904c72ae43be7394203d5f.xml
# saving: 0817_labels\87a7eacfadbc4224a9badacbc801238b.xml
# saving: 0817_labels\8e7d53ada5584ae5867041b57187d9e5.xml
# saving: 0817_labels\903c818cb03749eca1b09eb0aa815770.xml
# saving: 0817_labels\9402ab7880d64add9681326eafa33b58.xml
# saving: 0817_labels\967b4821873e44e39a033f301fc0ab87.xml
# saving: 0817_labels\9d97c3f22b6c4004b924834515d66fd7.xml
# saving: 0817_labels\a29568e42e20404d888bb0962c084389.xml
# saving: 0817_labels\a6e7345b870c405b9b92cde6eb7db797.xml
# saving: 0817_labels\a8657447b27f496a87a71218f915aee3.xml
# saving: 0817_labels\ab30726c1aae4cb19138feef846be161.xml
# saving: 0817_labels\ac5d934dc937482088bb399b427a25d0.xml
# saving: 0817_labels\acc3c738bceb48a899224197d3d882de.xml
# saving: 0817_labels\ad6013bb1f234bca837e49192947b859.xml
# saving: 0817_labels\aff2d849d04d491e9263aa6a6f445e8e.xml
# saving: 0817_labels\b7af94d57bc1459baeb017a7b293b6c4.xml
# saving: 0817_labels\bb92d4b8756040fabadb9641b6a016c2.xml
# saving: 0817_labels\c4c8aa2d20be4c3e83bc1dc26b294486.xml
# saving: 0817_labels\c5155ee5fe77493ab188b1f67a1c11d1.xml
# saving: 0817_labels\c6ca382c2c8e44ffaa3df9e596a4c058.xml
# saving: 0817_labels\c7565a8e6e4f4bf39133728773a293b4.xml
# saving: 0817_labels\ca50fe0dd36b42dbbbb8ca797f35f3b1.xml
# saving: 0817_labels\d1617ffc409f46149571ab23805f80c8.xml
# saving: 0817_labels\d2ea9defd7394433a61403c8c2d3419a.xml
# saving: 0817_labels\d3696d8f221b4763acc5207f1970bf4b.xml
# saving: 0817_labels\da580d47bbae4a6b906a2343b08b63d4.xml
# saving: 0817_labels\e03b4096476544cca4d95dca1d2018a0.xml
# saving: 0817_labels\e507989c7925471a9af1a45cae81f898.xml
# saving: 0817_labels\e634dce08cf3455798ad7454483a7bce.xml
# saving: 0817_labels\f00d9d85b6554d75812b96adb8f48270.xml
# saving: 0817_labels\f126f5d68312404cb37c5596df4544d9.xml
# saving: 0817_labels\f227b5e7ef0a468fbe151070fa7e8d06.xml
# saving: 0817_labels\fa3b1da56ba24a08920a416520455dc3.xml
# saving: 0817_labels\fcffce95128141bf8616a82705048648.xml
# saving: 0817_labels\fdd1d1e5634c4962bb7f2bfec3c48b76.xml
# saving: 0817_labels\ff01d6e216624d928445936d42181b21.xml

# %%
idx = 0
this_bird = bird_df.loc[idx_0817[idx]]
image_object = mpimg.imread(this_bird.image)
plt.imshow(image_object)

# %%
# using EfficientDet

# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
    while "models" in pathlib.Path.cwd().parts:
        os.chdir('..')
elif not pathlib.Path('models').exists():
    # !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# Updating files:  57% (1480/2584)
# Updating files:  58% (1499/2584)
# Updating files:  59% (1525/2584)
# Updating files:  60% (1551/2584)
# Updating files:  61% (1577/2584)
# Updating files:  62% (1603/2584)
# Updating files:  63% (1628/2584)
# Updating files:  64% (1654/2584)
# Updating files:  65% (1680/2584)
# Updating files:  66% (1706/2584)
# Updating files:  67% (1732/2584)
# Updating files:  68% (1758/2584)
# Updating files:  69% (1783/2584)
# Updating files:  70% (1809/2584)
# Updating files:  71% (1835/2584)
# Updating files:  72% (1861/2584)
# Updating files:  73% (1887/2584)
# Updating files:  74% (1913/2584)
# Updating files:  75% (1938/2584)
# Updating files:  76% (1964/2584)
# Updating files:  77% (1990/2584)
# Updating files:  78% (2016/2584)
# Updating files:  79% (2042/2584)
# Updating files:  80% (2068/2584)
# Updating files:  81% (2094/2584)
# Updating files:  82% (2119/2584)
# Updating files:  83% (2145/2584)
# Updating files:  84% (2171/2584)
# Updating files:  85% (2197/2584)
# Updating files:  86% (2223/2584)
# Updating files:  87% (2249/2584)
# Updating files:  88% (2274/2584)
# Updating files:  89% (2300/2584)
# Updating files:  90% (2326/2584)
# Updating files:  91% (2352/2584)
# Updating files:  92% (2378/2584)
# Updating files:  93% (2404/2584)
# Updating files:  94% (2429/2584)
# Updating files:  95% (2455/2584)
# Updating files:  96% (2481/2584)
# Updating files:  97% (2507/2584)
# Updating files:  98% (2533/2584)
# Updating files:  99% (2559/2584)
# Updating files: 100% (2584/2584)
# Updating files: 100% (2584/2584), done.

# %%
# %%bash
# # Install the Object Detection API
#
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf2/setup.py .
# python -m pip install .
# Out:
# Couldn't find program: 'bash'

# %%
import matplotlib
import matplotlib.pyplot as plt

import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf


from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import colab_utils
from object_detection.builders import model_builder

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-130-42ea925d969f> in <module>
#      17
#      18
# ---> 19 from object_detection.utils import label_map_util
#      20 from object_detection.utils import config_util
#      21 from object_detection.utils import visualization_utils as viz_utils
#
# ~\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research\object_detection\utils\label_map_util.py in <module>
#      27 import tensorflow.compat.v1 as tf
#      28 from google.protobuf import text_format
# ---> 29 from object_detection.protos import string_int_label_map_pb2
#      30
#      31 _LABEL_OFFSET = 1
#
# ImportError: cannot import name 'string_int_label_map_pb2' from 'object_detection.protos' (C:\Users\pui_s\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research\object_detection\protos\__init__.py)

# %%
import sys
sys.path
if r'C:\Users\pui_s\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research' not in sys.path:
    sys.path.insert(0, r'C:\Users\pui_s\Documents\concordia-bootcamps\FinalProject-BirdBox\BirdBox_helping_drone_detect_bird\models\research')

# %%
sys.path
# Out:
# ['C:\\Users\\pui_s\\Documents\\concordia-bootcamps\\FinalProject-BirdBox\\BirdBox_helping_drone_detect_bird\\models\\research',
#  'C:\\Users\\pui_s\\Documents\\concordia-bootcamps\\FinalProject-BirdBox\\BirdBox_helping_drone_detect_bird',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\python39.zip',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\DLLs',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\lib',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39',
#  '',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\win32',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\win32\\lib',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\Pythonwin',
#  'C:\\Users\\pui_s\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages',
#  'C:\\Users\\pui_s\\AppData\\Roaming\\Python\\Python39\\site-packages\\IPython\\extensions',
#  'C:\\Users\\pui_s\\.ipython']

# %%
# https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md

# %%
# !py -m pip list
# Out:
# Package                  Version
# ------------------------ -------------------
# absl-py                  0.12.0
# anyio                    3.2.0
# argon2-cffi              20.1.0
# astor                    0.8.1
# astunparse               1.6.3
# async-generator          1.10
# attrs                    21.2.0
# autograd                 1.3
# autograd-gamma           0.5.0
# Babel                    2.9.1
# backcall                 0.2.0
# bash_kernel              0.7.2
# beautifulsoup4           4.9.3
# bleach                   3.3.0
# bs4                      0.0.1
# cachetools               4.2.2
# certifi                  2020.12.5
# cffi                     1.14.5
# chardet                  3.0.4
# Christofides             1.0.1
# click                    8.0.1
# colorama                 0.4.4
# configparser             5.0.2
# cycler                   0.10.0
# Cython                   0.29.24
# decorator                4.4.2
# defusedxml               0.7.1
# dload                    0.6
# entrypoints              0.3
# fake-useragent           0.1.11
# findspark                1.4.2
# Flask                    2.0.1
# flatbuffers              1.12
# formulaic                0.2.3
# future                   0.18.2
# gast                     0.4.0
# gensim                   4.0.1
# gevent                   21.1.2
# google-api-core          1.31.0
# google-auth              1.30.1
# google-auth-oauthlib     0.4.4
# google-cloud-core        1.7.1
# google-pasta             0.2.0
# googleapis-common-protos 1.53.0
# greenlet                 1.1.0
# grpcio                   1.34.1
# h11                      0.9.0
# h2                       3.2.0
# h5py                     3.1.0
# hiveplot                 2017.10.17.21.7
# hmmlearn                 0.2.5
# hpack                    3.0.0
# hstspreload              2021.7.5
# httpcore                 0.9.1
# httpx                    0.13.3
# hyperframe               5.2.0
# idna                     2.10
# imageio                  2.9.0
# interface-meta           1.2.3
# ipykernel                5.5.5
# ipython                  7.23.1
# ipython-genutils         0.2.0
# ipywidgets               7.6.3
# itsdangerous             2.0.1
# Janitor                  0.1.1
# jedi                     0.18.0
# Jinja2                   3.0.1
# joblib                   1.0.1
# json5                    0.9.5
# jsonschema               3.2.0
# jupyter                  1.0.0
# jupyter-client           6.1.12
# jupyter-console          6.4.0
# jupyter-core             4.7.1
# jupyter-server           1.8.0
# jupyterlab               3.0.16
# jupyterlab-pygments      0.1.2
# jupyterlab-server        2.6.0
# jupyterlab-widgets       1.0.0
# Keras                    2.4.3
# keras-nightly            2.5.0.dev2021032900
# Keras-Preprocessing      1.1.2
# kiwisolver               1.3.1
# lifelines                0.26.0
# linearmodels             4.24
# llvmlite                 0.36.0
# lxml                     4.6.3
# lyricsgenius             3.0.1
# Markdown                 3.3.4
# MarkupSafe               2.0.1
# matplotlib               3.4.2
# matplotlib-inline        0.1.2
# mistune                  0.8.4
# more-itertools           8.8.0
# mpmath                   1.2.1
# munkres                  1.1.4
# mypy-extensions          0.4.3
# nbclassic                0.3.1
# nbclient                 0.5.3
# nbconvert                6.0.7
# nbformat                 5.1.3
# nest-asyncio             1.5.1
# networkx                 2.5.1
# nltk                     3.6.2
# notebook                 6.4.0
# numba                    0.53.1
# numpy                    1.19.5
# nxviz                    0.6.3
# oauthlib                 3.1.0
# opencv-python            4.5.2.54
# opt-einsum               3.3.0
# packaging                20.9
# palettable               3.3.0
# pandas                   1.2.4
# pandas-datareader        0.9.0
# pandocfilters            1.4.3
# parso                    0.8.2
# patsy                    0.5.1
# pexpect                  4.8.0
# pickleshare              0.7.5
# Pillow                   8.2.0
# pip                      21.2.1
# prometheus-client        0.10.1
# prompt-toolkit           3.0.18
# property-cached          1.6.4
# protobuf                 3.17.1
# ptyprocess               0.7.0
# py4j                     0.10.9
# pyasn1                   0.4.8
# pyasn1-modules           0.2.8
# pycodestyle              2.3.1
# pycparser                2.20
# Pygments                 2.9.0
# pyhdfe                   0.1.0
# pynndescent              0.5.3
# pyparsing                2.4.7
# pyprojroot               0.2.0
# pyrsistent               0.17.3
# pyspark                  3.1.2
# python-dateutil          2.8.1
# python-Levenshtein       0.12.2
# python-magic             0.4.22
# python-resize-image      1.1.19
# pytz                     2021.1
# pywin32                  300
# pywinpty                 1.1.1
# PyYAML                   5.4.1
# pyzmq                    22.0.3
# qtconsole                5.1.0
# QtPy                     1.9.0
# regex                    2021.7.6
# requests                 2.25.1
# requests-oauthlib        1.3.0
# rfc3986                  1.5.0
# rsa                      4.7.2
# scikit-learn             0.24.2
# scipy                    1.6.3
# seaborn                  0.11.1
# selenium                 3.141.0
# Send2Trash               1.5.0
# setuptools               56.0.0
# six                      1.15.0
# smart-open               5.1.0
# sniffio                  1.2.0
# soupsieve                2.2.1
# splinter                 0.14.0
# statsmodels              0.12.2
# sympy                    1.8
# tensorboard              2.5.0
# tensorboard-data-server  0.6.1
# tensorboard-plugin-wit   1.8.0
# tensorflow-estimator     2.5.0
# tensorflow-gpu           2.5.0
# tensorflow-hub           0.12.0
# termcolor                1.1.0
# terminado                0.10.0
# testpath                 0.5.0
# threadpoolctl            2.1.0
# tornado                  6.1
# tqdm                     4.61.1
# traitlets                5.0.5
# typing-extensions        3.7.4.3
# umap-learn               0.5.1
# Unidecode                1.2.0
# urllib3                  1.26.4
# wcwidth                  0.2.5
# webencodings             0.5.1
# websocket-client         1.1.0
# Werkzeug                 2.0.1
# wheel                    0.36.2
# widgetsnbextension       3.5.1
# wikipedia                1.4.0
# wrapt                    1.12.1
# wsgi-oauth2              0.2.2
# xvfbwrapper              0.2.9
# zope.event               4.5.0
# zope.interface           5.4.0
