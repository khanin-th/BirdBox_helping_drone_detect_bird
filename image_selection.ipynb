# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from glob import glob
import os

# %%
# getting all the images 
IMAGE_PATH = r'E:\Download\TensorflowObjectDetection\TFODCourse\Tensorflow\workspace\images\test'
images = list(set(glob(os.path.join(IMAGE_PATH, '*'))) - set(glob(os.path.join(IMAGE_PATH, '*.xml'))))

# %%
def select_image(i):
    a = None
    image_object = mpimg.imread(images[i])
    ax.imshow(image_object)
    plt.show()
    print(images[i])
    a = input('select ? (y/n/e)')
    if a.lower() == 'y':
        !"copy os.path.join(image.split('.')[0], '.*') I:\select_birds"
    if a.lower() == 'e':
        return None
    fig.clf()
    return select_image(i+1)

# %%
# calling the function
i = 0
fig, ax = plt.subplots()
select_image(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-80708c2fa5f2> in <module>
#       2 i = 0
#       3 fig, ax = plt.subplots()
# ----> 4 select_image(i)
#
# <ipython-input-51-4f15af7d2491> in select_image(i)
#       3     image_object = mpimg.imread(images[i])
#       4     ax.imshow(image_object)
# ----> 5     ax.show()
#       6     print(images[i])
#       7     a = input('select ? (y/n/e)')
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
